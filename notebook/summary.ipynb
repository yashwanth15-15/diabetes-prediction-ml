# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from sklearn.metrics import confusion_matrix, classification_report

# %%
df = pd.read_csv("../data/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print("""
Preprocessing Steps:
1. Zero-value columns replaced using median per Age-bin (5 bins)
2. Feature engineering:
   - Glucose_Insulin_Ratio
   - BMI_Age
   - Is_Obese
   - Is_High_Glucose
3. Standard scaling
4. SMOTE oversampling on training set
""")
# Out:
# Preprocessing Steps:
# 1. Zero-value columns replaced using median per Age-bin (5 bins)
# 2. Feature engineering:
#    - Glucose_Insulin_Ratio
#    - BMI_Age
#    - Is_Obese
#    - Is_High_Glucose
# 3. Standard scaling
# 4. SMOTE oversampling on training set

# %%
model = joblib.load("../models/best_model_lightgbm.pkl")
scaler = joblib.load("../models/scaler.pkl")

print("Model Loaded:", model.__class__.__name__)
# Out:
# Model Loaded: LGBMClassifier

# %%
from sklearn.metrics import confusion_matrix

# manually load your saved confusion matrix info if needed
cm = np.array([[79,21],[15,39]])
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
from IPython.display import Image, display

print("SHAP Summary Plot:")
display(Image(filename="../models/shap_summary.png"))

print("SHAP Bar Plot:")
display(Image(filename="../models/shap_bar.png"))

print("SHAP Dependence Plot:")
display(Image(filename="../models/shap_dependence_GIR.png"))
# Out:
# SHAP Summary Plot:
# SHAP Bar Plot:
# SHAP Dependence Plot:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 10
#       7 display(Image(filename="../models/shap_bar.png"))
#       9 print("SHAP Dependence Plot:")
# ---> 10 display(Image(filename="../models/shap_dependence_GIR.png"))
#
# File D:\machinelearning_projects\diabetes-prediction-ml\venv\Lib\site-packages\IPython\core\display.py:1025, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#    1023 self.unconfined = unconfined
#    1024 self.alt = alt
# -> 1025 super(Image, self).__init__(data=data, url=url, filename=filename,
#    1026         metadata=metadata)
#    1028 if self.width is None and self.metadata.get('width', {}):
#    1029     self.width = metadata['width']
#
# ...

# %%
import joblib
import pandas as pd

model = joblib.load("../models/best_model_lightgbm.pkl")
scaler = joblib.load("../models/scaler.pkl")

# Load dataset to get final columns
df = pd.read_csv("../data/diabetes.csv")
print("Columns in model.feature_name_ (if available):")
print(getattr(model, "feature_name_", None))
# Out:
# Columns in model.feature_name_ (if available):
# ['Column_0', 'Column_1', 'Column_2', 'Column_3', 'Column_4', 'Column_5', 'Column_6', 'Column_7', 'Column_8', 'Column_9', 'Column_10', 'Column_11']

# %%
display(Image(filename="../models/shap_dependence.png"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 display(Image(filename="../models/shap_dependence.png"))
#
# File D:\machinelearning_projects\diabetes-prediction-ml\venv\Lib\site-packages\IPython\core\display.py:1025, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#    1023 self.unconfined = unconfined
#    1024 self.alt = alt
# -> 1025 super(Image, self).__init__(data=data, url=url, filename=filename,
#    1026         metadata=metadata)
#    1028 if self.width is None and self.metadata.get('width', {}):
#    1029     self.width = metadata['width']
#
# File D:\machinelearning_projects\diabetes-prediction-ml\venv\Lib\site-packages\IPython\core\display.py:343, in DisplayObject.__init__(self, data, url, filename, metadata)
#     340 elif self.metadata is None:
# ...
